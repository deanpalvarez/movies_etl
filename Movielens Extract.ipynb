# %%
import pandas as pd

# %%
movies_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
movies_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
movies_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 10165  False                   NaN      0
# 26641  False                   NaN      0
# 26120  False                   NaN      0
# 713    False                   NaN      0
# 31898  False                   NaN      0
#
#                                                   genres  \
# 10165                      [{'id': 18, 'name': 'Drama'}]
# 26641                   [{'id': 53, 'name': 'Thriller'}]
# 26120  [{'id': 27, 'name': 'Horror'}, {'id': 37, 'nam...
# 713    [{'id': 16, 'name': 'Animation'}, {'id': 18, '...
# 31898  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                           homepage      id    imdb_id original_language  \
# 10165                          NaN   50536  tt0108410                en
# 26641  http://thesuspectmovie.com/  228245  tt2073121                en
# 26120                          NaN   47914  tt0076915                en
# 713                            NaN   40651  tt0113429                en
# 31898    http://www.lovemylife.jp/   40701  tt0923779                ja
#
#                                           original_title  \
# 10165                                       Twenty Bucks
# 26641                                        The Suspect
# 26120                                  The White Buffalo
# 713    Institute Benjamenta, or This Dream People Cal...
# 31898                                          ラブ・マイ・ライフ
#
#                                                 overview  ... release_date  \
# 10165  A story about the life of a twenty dollar bill...  ...   1993-10-21
# 26641  Two African American social scientists pose as...  ...   2013-10-16
# 26120  In this strange western version of JAWS, Wild ...  ...   1977-05-01
# 713    Jakob arrives at the Institute Benjamenta (run...  ...   1995-08-01
# 31898  Ichiko and Eri are two beautiful Japanese univ...  ...   2006-12-09
#
#       revenue runtime                                   spoken_languages  \
# 10165     0.0    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 26641     0.0    89.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 26120     0.0    97.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 713       0.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 31898     0.0    96.0               [{'iso_639_1': 'ja', 'name': '日本語'}]
#
#          status                                            tagline  \
# 10165  Released  When you pass the buck, the last thing you exp...
# 26641  Released                                                NaN
# 26120  Released  Two legendary enemies unite to fight the charg...
# 713    Released                                                NaN
# 31898  Released                                                NaN
#
#                                                    title  video vote_average  \
# 10165                                       Twenty Bucks  False          5.9
# 26641                                        The Suspect  False          5.5
# 26120                                  The White Buffalo  False          5.3
# 713    Institute Benjamenta, or This Dream People Cal...  False          7.7
# 31898                                       Love My Life  False          5.4
#
#       vote_count
# 10165       21.0
# 26641       18.0
# 26120       25.0
# 713         11.0
# 31898        4.0
#
# [5 rows x 24 columns]
